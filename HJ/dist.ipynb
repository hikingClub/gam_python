# %%
import requests
import json

url = "https://metalink.k-knowledge.kr/openapi/metadata/dist"
api_key = "dxygklxq8i4h2o7whfoup901cwn3x0r48qkfq7zud8f1gagk20i45for0zfb9yej"

headers = {
    "api_key": api_key  
}

params = {"from" : "2024-07-20",
        "until" : "2024-07-20",
        'page' : 1,
        'size' : 1,
        "type" : 'json'}

response = requests.get(url, headers=headers, params=params)

# 응답 처리
if response.status_code == 200:
    data = response.json()
    pretty_json = json.dumps(data, indent=4, ensure_ascii=False) # pretty print

    print("데이터 조회 성공:", pretty_json)
else:
    print("데이터 조회 실패:", response.status_code, response.text)
# Out:
# 데이터 조회 성공: {
#     "header": {
#         "totalCount": 152973,
#         "page": 1,
#         "size": 1,
#         "from": "2024-07-20",
#         "until": "2024-07-20",
#         "base_url": "https://k-knowledge.kr/srch/read.jsp?id="
#     },
#     "items": [
#         {
#             "status": "I",
#             "type": "T003",
#             "classifications": [
#                 "분야> 과학> 생물학"
#             ],
#             "title": {
#                 "org": "만주잎벌레",
#                 "alt": [],
#                 "partNo": "",
#                 "partName": ""
#             },
#             "subjects": [],
#             "description": {
#                 "abstract": {
#                     "org": "만주잎벌레",
#                     "alt": []
#                 },
#                 "toc": {
#                     "org": "",
#                     "alt": []
#                 },
#                 "summary": {
#                     "org": "",
#                     "alt": []
#                 }
#             },
#             "publisher": {
#                 "org": "국립중앙과학관",
#                 "alt": [],
#                 "location": ""
#             },
#             "contributors": [
#                 {
#                     "role": "author",
#                     "org": "국립중앙과학관",
#                     "alt": [],
#                     "affiliation": []
#                 }
#             ],
#             "date": {
#                 "created": "2018-04-16"
#             },
#             "language": {
#                 "org": "ko",
#                 "alt": []
#             },
#             "identifier": {
#                 "url": "https://k-knowledge.kr/srch/read.jsp?id=5541462",
#                 "site": "100110000_54018409_000"
#             },
#             "format": {
#                 "media": "",
#                 "size": 0,
#                 "extend": 0
#             },
#             "relation": {
#                 "related": [],
#                 "isPartOf": [],
#                 "hasPartOf": [],
#                 "reference": [],
#                 "citation": [],
#                 "referencedBy": [],
#                 "publication": [],
#                 "journal": [],
#                 "form": [],
#                 "registration": []
#             },
#             "coverage": {},
#             "right": {
#                 "license": [],
#                 "isFree": "FREE",
#                 "rightHolder": []
#             },
#             "audience": null,
#             "itemId": 5541462
#         }
#     ]
# }
